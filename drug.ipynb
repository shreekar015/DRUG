# %%
import pandas as pd
import numpy as np

from sklearn.svm import SVC #support vector classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt

# %%
df =pd.read_csv('1614141926_drugEffects.csv').drop(columns=['Unnamed: 0'])
df.head()
# Out:
#         urlDrugName  rating         effectiveness  \
# 0         enalapril       4      Highly Effective
# 1  ortho-tri-cyclen       1      Highly Effective
# 2           ponstel      10      Highly Effective
# 3          prilosec       3  Marginally Effective
# 4            lyrica       2  Marginally Effective
#
#                                 condition          sideEffects
# 0  management of congestive heart failure    Mild Side Effects
# 1                        birth prevention  Severe Side Effects
# 2                        menstrual cramps      No Side Effects
# 3                             acid reflux    Mild Side Effects
# 4                            fibromyalgia  Severe Side Effects

# %%
df['urlDrugName'].value_counts().head(15).plot(kind='bar')
plt.rcParams['figure.figsize']=(10,7)
plt.show()

# %%
# check the ratings of the drugs

df['rating'].value_counts().head(15).plot(kind='bar')
plt.xlabel('ratings')
plt.show()

# %%
# check the effectiveness of the drugs

df['effectiveness'].value_counts().plot(kind='pie')
plt.show()

# %%
# check the various conditions the medicine cures (top 10) since they are over thousand

df['condition'].value_counts().head(15).plot(kind='bar')
plt.xlabel('condition')
plt.show()

# %%
target=df.pop('sideEffects')
df.head()
# Out:
#         urlDrugName  rating         effectiveness  \
# 0         enalapril       4      Highly Effective
# 1  ortho-tri-cyclen       1      Highly Effective
# 2           ponstel      10      Highly Effective
# 3          prilosec       3  Marginally Effective
# 4            lyrica       2  Marginally Effective
#
#                                 condition
# 0  management of congestive heart failure
# 1                        birth prevention
# 2                        menstrual cramps
# 3                             acid reflux
# 4                            fibromyalgia

# %%
#let convert categorical data to numeric 

cols=['urlDrugName','effectiveness','condition']
for x in cols:
    df[x]=pd.factorize(df[x])[0]
    
target=pd.factorize(target)[0]
df.head()
# Out:
#    urlDrugName  rating  effectiveness  condition
# 0            0       4              0          0
# 1            1       1              0          1
# 2            2      10              0          2
# 3            3       3              1          3
# 4            4       2              1          4

# %%
# scaling the data before modelling

scaler=StandardScaler()
df=scaler.fit_transform(df)
df
# Out:
# array([[-1.21297976, -1.02349444, -1.04689456, -0.94221638],
#        [-1.20449215, -2.04490682, -1.04689456, -0.93987936],
#        [-1.19600454,  1.01933033, -1.04689456, -0.93754234],
#        ...,
#        [ 0.35722814, -1.70443603, -0.41222112,  2.38803771],
#        [ 3.03931298,  0.33838874,  0.85712577, -0.67112201],
#        [ 1.16355111, -1.02349444,  1.49179921, -0.74123262]])

# %% [markdown]
# # Split data

# %%
x_train,x_test,y_train,y_test = train_test_split(df,target, test_size=.3)

# %% [markdown]
# # using SVM

# %%
#using SVM

svm_clf=SVC().fit(x_train,y_train)

svm_pred=svm_clf.predict(x_test)

print(classification_report(y_test,svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.58      0.51       299
#            1       0.39      0.48      0.43       110
#            2       0.57      0.54      0.55       275
#            3       0.41      0.22      0.28        60
#            4       0.41      0.28      0.33       189
#
#     accuracy                           0.47       933
#    macro avg       0.45      0.42      0.42       933
# weighted avg       0.47      0.47      0.46       933

# %% [markdown]
# # using random forest

# %%
#using random forest


rf_clf=RandomForestClassifier().fit(x_train,y_train)

rf_pred=rf_clf.predict(x_test)

print(classification_report(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.51      0.47       299
#            1       0.35      0.38      0.37       110
#            2       0.57      0.53      0.55       275
#            3       0.45      0.37      0.40        60
#            4       0.43      0.38      0.41       189
#
#     accuracy                           0.46       933
#    macro avg       0.45      0.43      0.44       933
# weighted avg       0.47      0.46      0.46       933

# %% [markdown]
# # using decision tree

# %%
# using decision tree 

from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train,y_train)
prediction=clf.predict(x_test)

# %%
prediction
# Out:
# array([2, 4, 4, 0, 0, 4, 1, 4, 4, 4, 2, 0, 2, 0, 2, 2, 4, 2, 0, 3, 2, 0,
#        0, 0, 1, 2, 2, 2, 2, 2, 2, 4, 2, 4, 0, 0, 0, 4, 0, 1, 2, 4, 0, 2,
#        2, 0, 0, 4, 2, 3, 0, 1, 0, 2, 4, 3, 2, 0, 4, 4, 1, 0, 2, 3, 2, 4,
#        4, 4, 0, 0, 2, 1, 0, 0, 4, 0, 0, 2, 4, 2, 2, 2, 1, 1, 0, 0, 0, 2,
#        0, 2, 2, 4, 4, 1, 0, 0, 0, 0, 1, 0, 0, 0, 4, 1, 0, 1, 2, 0, 2, 0,
#        0, 2, 0, 4, 3, 4, 0, 4, 2, 2, 4, 4, 4, 4, 4, 2, 0, 0, 1, 0, 0, 2,
#        2, 1, 1, 4, 1, 1, 4, 3, 2, 0, 0, 2, 0, 1, 0, 4, 3, 0, 4, 2, 2, 0,
#        1, 0, 4, 1, 1, 2, 0, 1, 0, 1, 2, 2, 2, 2, 0, 0, 0, 1, 2, 0, 2, 0,
#        2, 2, 0, 0, 0, 0, 4, 2, 4, 4, 0, 2, 0, 0, 2, 0, 1, 0, 0, 3, 1, 1,
#        1, 1, 2, 2, 2, 0, 0, 0, 2, 2, 2, 1, 0, 2, 2, 0, 4, 2, 0, 0, 2, 0,
#        2, 0, 4, 3, 0, 0, 2, 0, 0, 2, 2, 2, 0, 1, 4, 0, 0, 1, 0, 4, 4, 4,
#        0, 0, 0, 2, 0, 2, 2, 0, 2, 1, 3, 2, 2, 0, 4, 4, 1, 2, 0, 0, 0, 4,
#        1, 4, 2, 0, 1, 2, 2, 0, 3, 3, 4, 2, 0, 3, 0, 0, 2, 2, 0, 2, 0, 2,
#        1, 2, 1, 1, 0, 2, 3, 2, 0, 3, 0, 2, 0, 4, 2, 2, 3, 0, 3, 3, 0, 2,
#        4, 2, 4, 1, 0, 0, 4, 1, 0, 1, 4, 2, 0, 4, 2, 0, 3, 2, 4, 1, 0, 0,
#        4, 0, 0, 4, 4, 4, 2, 4, 1, 4, 2, 1, 0, 0, 2, 2, 2, 4, 2, 0, 2, 1,
#        2, 4, 1, 4, 2, 0, 2, 2, 0, 1, 0, 0, 4, 0, 4, 2, 0, 4, 0, 2, 4, 0,
#        2, 1, 2, 0, 2, 0, 2, 2, 0, 4, 0, 2, 2, 0, 3, 0, 0, 0, 0, 0, 2, 1,
#        2, 2, 0, 4, 2, 2, 0, 4, 2, 2, 1, 1, 4, 3, 2, 2, 0, 3, 2, 3, 0, 2,
#        0, 0, 0, 1, 0, 1, 0, 0, 0, 0, 2, 0, 4, 0, 2, 2, 0, 2, 3, 4, 0, 0,
#        2, 0, 4, 0, 3, 2, 1, 1, 3, 0, 4, 0, 2, 0, 2, 0, 0, 2, 0, 1, 0, 2,
#        4, 2, 0, 0, 0, 0, 1, 0, 1, 4, 0, 2, 2, 2, 2, 2, 2, 0, 0, 1, 0, 0,
#        2, 4, 2, 4, 0, 3, 4, 3, 4, 1, 2, 4, 4, 4, 0, 0, 3, 3, 0, 3, 0, 0,
#        3, 1, 4, 4, 0, 3, 1, 4, 0, 0, 0, 0, 0, 2, 2, 2, 0, 1, 0, 2, 2, 0,
#        3, 0, 0, 4, 0, 2, 0, 3, 0, 2, 4, 1, 0, 0, 0, 0, 0, 4, 2, 2, 0, 0,
#        3, 1, 4, 0, 4, 0, 2, 2, 0, 0, 0, 2, 2, 2, 3, 2, 2, 2, 4, 0, 4, 1,
#        3, 4, 2, 3, 4, 4, 2, 2, 0, 2, 1, 0, 2, 4, 0, 3, 4, 0, 0, 4, 3, 4,
#        2, 2, 1, 2, 0, 1, 0, 0, 4, 4, 4, 1, 2, 0, 0, 2, 1, 4, 0, 0, 2, 4,
#        0, 4, 0, 0, 2, 3, 0, 1, 1, 3, 4, 0, 0, 0, 2, 1, 3, 0, 0, 0, 0, 0,
#        4, 0, 0, 0, 0, 1, 3, 2, 4, 0, 2, 1, 0, 4, 2, 4, 4, 4, 2, 2, 2, 2,
#        0, 2, 4, 0, 1, 2, 1, 2, 2, 2, 0, 0, 2, 2, 0, 0, 0, 0, 4, 4, 0, 2,
#        0, 0, 2, 0, 3, 0, 0, 1, 0, 2, 2, 1, 2, 0, 1, 0, 1, 4, 3, 0, 0, 3,
#        2, 4, 0, 2, 0, 2, 4, 2, 0, 0, 4, 2, 0, 4, 0, 2, 0, 0, 1, 3, 1, 4,
#        0, 2, 1, 1, 0, 0, 2, 0, 2, 0, 2, 0, 4, 1, 1, 0, 1, 0, 0, 4, 2, 3,
#        0, 0, 0, 2, 3, 4, 1, 1, 2, 0, 4, 3, 4, 2, 2, 2, 2, 0, 4, 0, 4, 4,
#        0, 2, 0, 2, 3, 2, 2, 0, 2, 0, 0, 4, 2, 1, 2, 0, 3, 1, 0, 1, 2, 0,
#        2, 0, 0, 2, 0, 4, 2, 0, 0, 0, 0, 4, 2, 2, 2, 1, 4, 2, 4, 4, 2, 2,
#        4, 3, 2, 4, 1, 2, 2, 3, 0, 2, 2, 0, 0, 0, 2, 2, 4, 2, 4, 1, 1, 4,
#        0, 4, 4, 0, 2, 1, 1, 0, 4, 2, 0, 4, 2, 0, 2, 0, 4, 4, 4, 0, 0, 4,
#        0, 0, 0, 0, 1, 0, 0, 3, 2, 2, 2, 0, 2, 4, 2, 0, 0, 4, 0, 2, 2, 0,
#        0, 4, 4, 0, 4, 2, 0, 0, 4, 4, 2, 1, 0, 2, 0, 2, 0, 2, 0, 4, 4, 3,
#        4, 0, 0, 1, 4, 2, 4, 4, 0, 0, 4, 1, 1, 2, 3, 2, 2, 0, 4, 0, 1, 0,
#        2, 0, 2, 0, 2, 1, 1, 0, 0], dtype=int64)

# %%
from sklearn.datasets import load_iris
iris = load_iris()
df,target = iris.data, iris.target
clf = tree.DecisionTreeClassifier()
clf = clf.fit(df, target)
tree.plot_tree(clf)
# Out:
# [Text(279.0, 348.81, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(236.07692307692307, 285.39, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(321.9230769230769, 285.39, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(171.69230769230768, 221.97, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(85.84615384615384, 158.55, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(42.92307692307692, 95.13, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(128.76923076923077, 95.13, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(257.53846153846155, 158.55, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(214.61538461538458, 95.13, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(300.46153846153845, 95.13, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(257.53846153846155, 31.710000000000036, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(343.38461538461536, 31.710000000000036, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(472.15384615384613, 221.97, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(429.23076923076917, 158.55, 'X[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(386.30769230769226, 95.13, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(472.15384615384613, 95.13, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(515.0769230769231, 158.55, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# # using KNN

# %%
 

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df,target)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([0, 2, 0, 2, 0, 0, 0, 2, 1, 2, 1, 1, 1, 2, 0, 2, 0, 1, 0, 0, 2, 2,
#        2, 0, 1, 0, 2, 2, 2, 2, 2, 0, 0, 0, 1, 1, 0, 1])

# %%
y_test
# Out:
# array([0, 2, 0, 2, 0, 0, 0, 2, 1, 2, 1, 1, 2, 2, 0, 2, 0, 1, 0, 0, 2, 2,
#        2, 0, 1, 0, 2, 2, 2, 2, 2, 0, 0, 0, 1, 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.9736842105263158
